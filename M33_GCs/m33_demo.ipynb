# %% [markdown]
# # <center >M33 Function Demo </center>
#
# Here we test and display how each function in `m33.py` works. If certain imports are repeated it is because each function is tested with the intent of running it off of a fresh kernel. This is so that we can ensure that the functions are running properly and can perform what is expected without depending on the kernel containing information from a previous cell.

# %% [markdown]
# ### 1. Testing `ccd_dict`
# #### <center>Purpose</center>

# %%
from m33 import ccd_dict
ccd_dictionary = ccd_dict()
# Out:
# ________________________________________________________________________________
# Dictionary created
# Example Key:Value pair:
# { Field2 chip1 : ['/home/ray/m33/astrometry_solved/r-SLOAN/Field2/chip1/1rf2c1.fits'] }

# %% [markdown]
# ### 2. Testing `mosaic_info`

# %%
from m33 import mosaic_info

import numpy as np
import pandas as pd

f1 = ['/home/ray/m33/raw_images/r-SLOAN/field1/mosaics/lbcb.20170918.075612.fits']
ra = 23.4044430
dec = 30.8929445
ID = 'demo ID'


mosaic_info(f1)
# Out:
# File:  lbcb.20170918.075612.fits
# Date: 2017-09-18
# Filter:  r-SLOAN
# Type: M33_1
# Camera: LBC_BLUE
# FWHM:  1.02
# ________________________________________

# %% [markdown]
# ### Testing `fits_info`

# %%
from m33 import fits_info
f1c1 = list(ccd_dictionary.values())[0]
fits_info(f1c1)
# Out:
# Date: 2017-09-18
# Filter:  r-SLOAN
# Type: M33_1
# ________________________________________

# %% [markdown]
# ### Testing `world2pix`

# %%
from m33 import world2pix
world2pix(f1c1[0], ra, dec)
# Out:
# array([1961.50633517, 4370.34850118])

# %% [markdown]
# ### Testing `psf`

# %%
from m33 import psf

r = [0,0.25,0.5,0.75,1,1.5]
pars = np.array([1,0.1,0.5,0.5])

psf(r,*pars)
# Out:
# array([1.        , 0.04366694, 0.03705132, 0.03356295, 0.03125   ,
#        0.02820857])

# %% [markdown]
# ### Testing `king`

# %%
from m33 import king
king(r,*pars)
# Out:
# array([1.14622927, 0.53072116, 0.5       , 0.50408991, 0.50933396,
#        0.51679541])

# %% [markdown]
# ### Testing `is_in_image`

# %%
from m33 import is_in_image
ra = [23.4044430,23.5272750]
dec = [30.8929445,30.7502023]
ID = ['yes','sure']
f1c1 = list(ccd_dict().values())[0][0]
is_in_image(ra, dec, ID, f1c1)
# Out:
# ________________________________________________________________________________
# Dictionary created
# Example Key:Value pair:
# { Field2 chip1 : ['/home/ray/m33/astrometry_solved/r-SLOAN/Field2/chip1/1rf2c1.fits'] }
#      id          chip         ra        dec            x            y  \
# 0   yes  Field1 chip1  23.404443  30.892944  1961.506335  4370.348501
# 1  sure  Field1 chip1  23.527275  30.750202   275.595057  2079.853778
#
#                                                 file   tag
# 0  /home/ray/m33/astrometry_solved/r-SLOAN/Field1...  f1c1
# 1  /home/ray/m33/astrometry_solved/r-SLOAN/Field1...  f1c1

# %% [markdown]
# ### Testing `is_in_filter`

# %%
import pandas as pd
from m33 import is_in_filter 
df = pd.read_csv('datasets/ma_clusters.csv')
is_in_filter(df, '_RA', '_DE',ID='Name')
# Out:
# ________________________________________________________________________________
# Dictionary created
# Example Key:Value pair:
# { Field2 chip1 : ['/home/ray/m33/astrometry_solved/r-SLOAN/Field2/chip1/1rf2c1.fits'] }
#             ccd   ID      frame_x      frame_y    x_coord    y_coord  \
# 0  Field1 chip1  U49  1501.110059  2821.252847  49.110059  49.252847
# 1  Field1 chip1  R12   212.808621   395.704188  49.808621  49.704188
# 2  Field1 chip1  R14   521.619909   934.812721  49.619909  49.812721
# 3  Field1 chip1  H10  2080.648035  3151.667320  49.648035  49.667320
# 4  Field1 chip2   M9  1013.660994   265.630535  49.660994  49.630535
# 5  Field1 chip2  C20   200.978991  3999.553396  49.978991  49.553396
# 6  Field2 chip3  U77   792.882002   911.317255  49.882002  49.317255
# 7  Field2 chip3  H10   441.769623  2892.578010  49.769623  49.578010
# 8  Field3 chip3  H38   384.865995  2132.077204  49.865995  49.077204
# 9  Field4 chip1  C38   939.262714  4214.495714  49.262714  49.495714
#
#                                                 chip        ra       dec  \
# 0  /home/ray/m33/astrometry_solved/r-SLOAN/Field1...  23.43792  30.79631
# 1  /home/ray/m33/astrometry_solved/r-SLOAN/Field1...  23.53350  30.64394
# 2  /home/ray/m33/astrometry_solved/r-SLOAN/Field1...  23.51033  30.67797
# 3  /home/ray/m33/astrometry_solved/r-SLOAN/Field1...  23.39625  30.81667
# 4  /home/ray/m33/astrometry_solved/r-SLOAN/Field1...  23.62583  30.63694
# 5  /home/ray/m33/astrometry_solved/r-SLOAN/Field1...  23.68417  30.87192
# 6  /home/ray/m33/astrometry_solved/r-SLOAN/Field2...  23.36967  30.69306
# 7  /home/ray/m33/astrometry_solved/r-SLOAN/Field2...  23.39625  30.81667
# 8  /home/ray/m33/astrometry_solved/r-SLOAN/Field3...  23.46750  30.48439
# 9  /home/ray/m33/astrometry_solved/r-SLOAN/Field4...  23.37792  30.37261
#
#     tag                                        cutout_data
# 0  f1c1  [[4623, 4599, 4649, 4613, 4621, 4622, 4574, 47...
# 1  f1c1  [[6133, 6388, 6963, 7834, 8329, 8080, 7721, 71...
# 2  f1c1  [[7241, 7166, 6797, 6770, 6680, 6547, 6529, 65...
# 3  f1c1  [[4010, 3996, 3994, 3979, 3978, 3935, 3932, 40...
# 4  f1c2  [[3815.0457, 3721.0986, 3685.451, 3727.3413, 3...
# 5  f1c2  [[3332.457, 3461.4387, 3420.4348, 3490.7341, 3...
# 6  f2c3  [[5254.4253, 5598.3857, 5775.6855, 5642.2227, ...
# 7  f2c3  [[3283.1091, 3331.837, 3456.8955, 3415.968, 34...
# 8  f3c3  [[5081.8433, 4985.1104, 4864.7837, 4864.987, 4...
# 9  f4c1  [[3904.6067, 3933.8623, 3927.9998, 3945.9312, ...

# %% [markdown]
# ### Testing `display_target`

# %%
from m33 import display_target
ra = 23.4044430
dec = 30.8929445
name = 'test_target'
display_target(ra,dec,name)
# Out:
# ________________________________________________________________________________
# Dictionary created
# Example Key:Value pair:
# { Field2 chip1 : ['/home/ray/m33/astrometry_solved/r-SLOAN/Field2/chip1/1rf2c1.fits'] }
# []

# %% [markdown]
# ### Testing `hwhm`

# %%
from m33 import hwhm
pars = np.asarray([4.2127931 , 2.19462083, 5.71225285, 0.4       ])
hwhm(pars)
# Out:
# 2.453037658697949

# %% [markdown]
# ### Testing `bkg_subtraction`

# %%
import pandas as pd
from m33 import bkg_subtraction
from m33 import is_in_filter
path = '/home/ray/Documents/projects/m33/datasets/'
file =  'ma_clusters.csv'

clusters = pd.read_csv(path+file)
find_clusters = is_in_filter(clusters,'_RA','_DE','Name','r-SLOAN')

cluster = 6
data = find_clusters['cutout_data'][cluster]
x0    = find_clusters['x_coord'][cluster]
y0    = find_clusters['y_coord'][cluster]
ID   = find_clusters['ID'][cluster]

bkgsubtracted = bkg_subtraction(data,inspect=True)
# Out:
# ________________________________________________________________________________
# Dictionary created
# Example Key:Value pair:
# { Field2 chip1 : ['/home/ray/m33/astrometry_solved/r-SLOAN/Field2/chip1/1rf2c1.fits'] }

# %% [markdown]
# ### Testing `make_isophote`

# %%
import pandas as pd
from m33 import is_in_filter
from m33 import make_isophote
path = '/home/ray/Documents/projects/m33/datasets/'
file =  'ma_clusters.csv'

clusters = pd.read_csv(path+file)
find_clusters = is_in_filter(clusters,'_RA','_DE','Name','r-SLOAN')

cluster = 1
data = find_clusters['cutout_data'][cluster]
x0    = find_clusters['x_coord'][cluster]
y0    = find_clusters['y_coord'][cluster]
ID   = find_clusters['ID'][cluster]

test = make_isophote(data, x0, y0, ID,inspect=True)
test
# Out:
# ________________________________________________________________________________
# Dictionary created
# Example Key:Value pair:
# { Field2 chip1 : ['/home/ray/m33/astrometry_solved/r-SLOAN/Field2/chip1/1rf2c1.fits'] }
# (<photutils.isophote.isophote.IsophoteList at 0x7f9255023ac0>,
#  [<Figure size 432x288 with 1 Axes>,
#   <Figure size 432x288 with 2 Axes>,
#   <Figure size 432x288 with 4 Axes>])

# %% [markdown]
# ### Testing `make_psf`

# %%
from m33 import make_psf
psf_stars = pd.read_csv('datasets/M33_psf_starlist.csv')
pars = make_psf(psf_stars, 'RA', 'DEC', 'ID', 'f1c1',inspect=True)
pars
# Out:
# ________________________________________________________________________________
# Dictionary created
# Example Key:Value pair:
# { Field2 chip1 : ['/home/ray/m33/astrometry_solved/r-SLOAN/Field2/chip1/1rf2c1.fits'] }
# (array([4.50187315, 2.11013507, 6.28654735, 0.4       ]),
#  [<Figure size 432x288 with 4 Axes>,
#   <Figure size 432x288 with 4 Axes>,
#   <Figure size 432x288 with 4 Axes>,
#   <Figure size 432x288 with 1 Axes>,
#   <Figure size 432x288 with 1 Axes>,
#   <Figure size 432x288 with 1 Axes>,
#   <Figure size 432x288 with 1 Axes>],
#  [4.772510340439071, 1.0762010817690106])

# %% [markdown]
# ### Testing `generate_psf`

# %%
from m33 import generate_psf
ok = generate_psf('r-SLOAN', 'f1c1')
ok
# Out:
# ________________________________________________________________________________
# Dictionary created
# Example Key:Value pair:
# { Field2 chip1 : ['/home/ray/m33/astrometry_solved/r-SLOAN/Field2/chip1/1rf2c1.fits'] }
#         filter   ccd          r0     alpha         beta  off      fwhm  \
# chip
# rf1c1  r-SLOAN  f1c1    4.501873  2.110135     6.286547  0.4  4.772510
# rf1c2  r-SLOAN  f1c2  300.109427  1.830830  7933.657335  0.4  5.069739
#
#          seeing
# chip
# rf1c1  1.076201
# rf1c2  1.143226

# %% [markdown]
# ### Testing `deconvolve_PSF`

# %% [markdown]
# ### Testing `fit_king`

# %% [markdown]
# ### Testing `px2distance`

# %% [markdown]
# ### Testing `get_parameters`

# %% [markdown]
# ### Testing `pipeline`
