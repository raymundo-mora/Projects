# %% [markdown]
# # Data Collection
#
# In this notebook we will generate the relevant datasets for analyzing the songs in your *Spotify* library. To make sure the code runs and

# %%
from bs4 import BeautifulSoup
from dotenv import dotenv_values
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from dotenv import dotenv_values
from dotenv import load_dotenv
load_dotenv()
import spotipy
from spotipy.oauth2 import SpotifyOAuth

scope = "user-library-read"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))

results = sp.current_user_saved_tracks(limit=2,offset=0)
data_dir = "datasets/"

# %%
results
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=0&limit=2',
#  'items': [{'added_at': '2023-04-04T23:47:45Z',
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
# ...

# %%
LIB['track.album.artists'][0]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#   'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#   'id': '7dGJo4pcD2V6oG8kP0tJRR',
#   'name': 'Eminem',
#   'type': 'artist',
#   'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}]

# %%
import pandas as pd

# %%
pd.DataFrame(pd.json_normalize(results['items']))
# Out:
#                added_at track.album.album_group track.album.album_type  \
# 0  2023-04-04T23:47:45Z                   album                  album
# 1  2023-03-30T11:28:56Z                  single                 single
#
#                                  track.album.artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
#
#                        track.album.available_markets  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 1  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
#
#                    track.album.external_urls.spotify  \
# 0  https://open.spotify.com/album/1kTlYbs28MXw7hw...
# 1  https://open.spotify.com/album/6XN8b2NIomlwPOo...
#
#                                     track.album.href          track.album.id  \
# 0  https://api.spotify.com/v1/albums/1kTlYbs28MXw...  1kTlYbs28MXw7hwO0NLYif
# 1  https://api.spotify.com/v1/albums/6XN8b2NIomlw...  6XN8b2NIomlwPOoBlILqXv
#
# ...

# %%
results.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results['items'][0]['track']['name']
# Out:
# 'Crazy In Love'

# %%
saved_tr = pd.DataFrame()

# %%
saved_tr = pd.concat([saved_tr,pd.json_normalize(results['items'])])

# %%
saved_tr.reset_index(drop=True)
# Out:
#                added_at track.album.album_group track.album.album_type  \
# 0  2023-04-04T23:47:45Z                   album                  album
# 1  2023-03-30T11:28:56Z                  single                 single
# 2  2023-04-04T23:47:45Z                   album                  album
# 3  2023-03-30T11:28:56Z                  single                 single
#
#                                  track.album.artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
#
#                        track.album.available_markets  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 1  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 2  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 3  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
#
#                    track.album.external_urls.spotify  \
# ...

# %%
offset = 0
limit = 50
saved_tracks = pd.DataFrame()

while True:
    # Fetch saved tracks with current offset and limit
    results = sp.current_user_saved_tracks(limit=limit, offset=offset)
    
    # Append fetched tracks to the list
    saved_tracks = pd.concat([saved_tracks,pd.json_normalize(results['items'])])
    
    # Check if there are more tracks to fetch
    if len(results['items']) < limit:
        # Break the loop if no more tracks found
        break
    else:
        # Increment the offset for the next request
        offset += limit

# %%
saved_tracks = saved_tracks.reset_index()

# %%
LIB = saved_tracks
saved_tracks.to_csv(data_dir+"LIB.csv")

# %% [markdown]
# ## genius Lyrics

# %%
import os
import requests
from dotenv import load_dotenv


# Get client ID and client secret from environment variables
GENIUS_CLIENT_ID = os.getenv('GENIUS_CLIENT_ID')
GENIUS_CLIENT_SECRET = os.getenv('GENIUS_CLIENT_SECRET')

def get_access_token():
    """Fetch access token from Genius API"""
    
    # Set API endpoint and headers
    endpoint = 'https://api.genius.com/oauth/token'
    headers = {'Content-Type': 'application/json'}
    
    # Set request payload
    data = {
        'client_id': GENIUS_CLIENT_ID,
        'client_secret': GENIUS_CLIENT_SECRET,
        'grant_type': 'client_credentials'
    }
    
    # Send API request
    response = requests.post(endpoint, headers=headers, json=data)
    
    # Check if request was successful
    if response.status_code == 200:
        # Extract access token from response
        data = response.json()
        access_token = data['access_token']
        
        return access_token
    else:
        print("Failed to fetch access token. Please check your client ID and client secret.")
        return None

def get_lyrics(song_title, artist_name):
    """Fetch lyrics of a song from Genius API"""
    
    # Fetch access token
    access_token = get_access_token()
    if not access_token:
        return None
    
    # Set API endpoint and headers
    endpoint = 'https://api.genius.com/search'
    headers = {'Authorization': f'Bearer {access_token}'}
    
    # Set query parameters
    params = {
        'q': f'{song_title} {artist_name}',
    }
    
    # Send API request
    response = requests.get(endpoint, headers=headers, params=params)
    
    # Check if request was successful
    if response.status_code == 200:
        # Extract lyrics from response
        data = response.json()
        hits = data['response']['hits']
        
        # Check if hits are found
        if hits:
            # Fetch the first hit (most relevant result)
            hit = hits[0]
            song_lyrics_url = hit['result']['url']
            
            # Fetch the lyrics from the song URL
            lyrics_response = requests.get(song_lyrics_url)
            soup = BeautifulSoup(lyrics_response.content,"html.parser")
            lyrics = str()
            for tag in soup.select('div[class^="Lyrics__Container"], .song_body-lyrics p'):
                t = tag.get_text(strip=True, separator='\n')
                if t:
                    lyrics += t 
            
            
            return lyrics
        else:
            print(f"No lyrics found for {song_title} by {artist_name}.")
            return None
    else:
        print("Failed to fetch lyrics. Please check your client ID and client secret.")
        return "API Call Failed"
        
# Example usage
song_title = 'Someone Like You'
artist_name = 'Adele'
lyrics = get_lyrics(song_title, artist_name)
if lyrics:
    print("Lyrics:")
    print(lyrics)
# Out:
# Lyrics:
# [Verse 1]
# I heard that you're settled down
# That you found a girl and you're married now
# I heard that your dreams came true
# Guess she gave you things I didn't give to you
# Old friend, why are you so shy?
# Ain't like you to hold back or hide from the light
# [Pre-Chorus]
# I hate to turn up out of the blue, uninvited
# But I couldn't stay away, I couldn't fight it
# I had hoped you'd see my face
# And that you'd be reminded that for me, it isn't over
# [Chorus]
# Never mind, I'll find someone like you
# I wish nothing but the best for you, too
# Don't forget me, I beg
# I remember you said
# Sometimes it lasts in love, but sometimes it hurts instead
# Sometimes it lasts in love, but sometimes it hurts instead
# [Verse 2]
# You know how the time flies
# Only yesterday was the time of our lives
# We were born and raised in a summer haze
# Bound by the surprise of our glory days
# [Pre-Chorus]
# I hate to turn up out of the blue, uninvited
# ...

# %%
LIB['track.artists'][0][0]['name']
# Out:
# 'Eminem'

# %%
CORPUS = pd.DataFrame()
import time
import numpy as np
from IPython.display import clear_output
total_tracks = len(LIB)
for i in LIB.index:
    
    song_title = LIB['track.name'][i]
    artist_name = LIB['track.artists'][i][0]['name']
    lyrics = get_lyrics(song_title, artist_name)
    CORPUS = pd.concat([CORPUS,pd.DataFrame({'artist':[artist_name],
                                             'song':[song_title],
                                             'lyrics':[lyrics]})]
                      )
    time.sleep(0.25)
    clear_output(wait=True)
    print(str(np.round(100*i/total_tracks,2))+"%"+f'       [{i}/{total_tracks}]   \n', flush=True)
    print(lyrics,flush=True)
# if lyrics:
#     print("Lyrics:")
#     print(lyrics)
# Out:
# 99.95%       [2059/2060]
#
# [Intro: Ericka Lee]
# Hello?
# Yeah, I just walked in
# Yeah, I'm good, you still working?
# Tonight
# , right now?
# Did I go out? Yeah, I went out, I went
# I went to a couple of clubs
# I never went to bed, shit
# Wine or water?
# Did you say something about a cold drink? I don't know
# I'm
# delirious
# [Verse 1: Drake]
# Cups of the rosé
# Bitches in my old phone
# I should call one and go home
# I've been in this club too long
# The woman that I would try
# Is happy with a good guy
# But I've been drinkin' so much
# That I'ma call her anyway and say
# [Chorus: Drake]
# Fuck that nigga that you love so bad
# I know you still think about the times we had
# I say fuck that nigga that you think you found
# And since you pick up, I know he's not around, oh, oh
# [Post-Chorus: Drake &
# Ericka Lee
# ]
# Are you drunk right now?
# I'm just sayin' you could do better
# Tell me, have you heard that lately?
# I'm just sayin' you could do better
# ...

# %%
CORPUS= CORPUS.reset_index()
CORPUS
# Out:
#               artist                                               song  \
# 0             Eminem                                      Crazy In Love
# 0  The White Stripes           Seven Nation Army - The Glitch Mob Remix
# 0   Beto Quintanilla                                    Alfredo Venegas
# 0       Taylor Swift  The Very First Night (Taylor's Version) (From ...
#
#                                               lyrics
# 0  [Intro: Heart (Sampled)]\nTell myself that I w...
# 0  [Instrumental Intro]\n[Verse 1]\nI'm gonna fig...
# 0                                               None
# 0  [Chorus]\nI wish I could fly\nI'd pick you up ...

# %%
d= get_lyrics('Alfredo Venegas',"Beto Quintanilla")
# Out:
# No lyrics found for Alfredo Venegas by Beto Quintanilla.

# %%
CORPUS = CORPUS.reset_index()

# %%
CORPUS.to_csv(data_dir+'lyrics.csv',index=False)

# %%
LYRICS = pd.read_csv(data_dir+'lyrics.csv')

# %%
LYRICS
# Out:
#                  artist                                               song  \
# 0                Eminem                                      Crazy In Love
# 1     The White Stripes           Seven Nation Army - The Glitch Mob Remix
# 2      Beto Quintanilla                                    Alfredo Venegas
# 3          Taylor Swift  The Very First Night (Taylor's Version) (From ...
# 4          Taylor Swift  Run (feat. Ed Sheeran) (Taylor’s Version) (Fro...
# ...                 ...                                                ...
# 2055             Eminem           Lose Yourself - From "8 Mile" Soundtrack
# 2056             Eminem                                    Till I Collapse
# 2057              Drake                                      Make Me Proud
# 2058              Drake                                          Headlines
# 2059              Drake                                       Marvins Room
#
#                                                  lyrics
# ...

# %%
LYRICS.loc[LYRICS['lyrics'] == ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7340\473527575.py in <module>
# ----> 1 LYRICS.loc[LYRICS['lyrics'] == nan]
#
# NameError: name 'nan' is not defined

# %%
type(LYRICS.iloc[2].lyrics)
# Out:
# float

# %%
LYRICS.loc[LYRICS['lyrics'].isna()]
# Out:
#                                  artist  \
# 2                      Beto Quintanilla
# 78               El Halcon De La Sierra
# 90                          Linkin Park
# 99                          Linkin Park
# 109                            WEEDMANE
# ...                                 ...
# 1864              Explosions In The Sky
# 1887                      Black Sabbath
# 1939  Chon Arauza Y Su Furia Colombiana
# 1958                             The xx
# 1960                         Whitesnake
#
#                                                 song lyrics
# 2                                    Alfredo Venegas    NaN
# 78                                   Pakas De A Kilo    NaN
# 90                                           Session    NaN
# 99                                          Foreword    NaN
# 109                    SUICIDE YEAR - airshade Remix    NaN
# ...                                              ...    ...
# ...

# %%
LIB
# Out:
#       index              added_at track.album.album_group  \
# 0         0  2023-04-04T23:47:45Z                   album
# 1         1  2023-03-30T11:28:56Z                  single
# 2         2  2023-03-30T01:49:21Z                   album
# 3         3  2023-03-30T00:07:23Z                   album
# 4         4  2023-03-30T00:07:18Z                   album
# ...     ...                   ...                     ...
# 2055      5  2016-05-24T09:41:01Z             compilation
# 2056      6  2016-05-24T09:40:58Z                   album
# 2057      7  2016-05-24T09:40:11Z                   album
# 2058      8  2016-05-24T09:39:42Z                   album
# 2059      9  2016-05-24T09:35:11Z                   album
#
#      track.album.album_type  \
# 0                     album
# 1                    single
# 2                     album
# 3                     album
# 4                     album
# ...                     ...
# 2055            compilation
# 2056                  album
# ...

# %%
from IPython.display import clear_output
for i in range(10):
    clear_output(wait=True)
    print(i, flush=True)
# Out:
# 9

# %%
LYRICS.loc[LYRICS['lyrics'] == 'API Call Failed']
# Out:
# Empty DataFrame
# Columns: [artist, song, lyrics]
# Index: []

# %%
artists = LIB['track.id'][0]
artists
# Out:
# '0bCCMwWTaYOcQ4v8EeEYmd'

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2059
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
def get_genre(track_id):
    
    # Get track info
    track_info = sp.track(track_id)
    
    # Get artist info
    artist_info = sp.artist(track_info['artists'][0]['id'])
    
    # Get genre
    genre = artist_info['genres']
    
    return genre

# %%
genres = []
for i in LIB.index:
    genre = get_genre(LIB['track.id'][i])
    genres.append(genre)
    clear_output(wait=True)
    print(i,flush=True)
    print(genre,flush=True)
# Out:
# 2059
# ['canadian hip hop', 'canadian pop', 'hip hop', 'rap', 'toronto rap']

# %%
LIB
# Out:
#       index              added_at track.album.album_group  \
# 0         0  2023-04-04T23:47:45Z                   album
# 1         1  2023-03-30T11:28:56Z                  single
# 2         2  2023-03-30T01:49:21Z                   album
# 3         3  2023-03-30T00:07:23Z                   album
# 4         4  2023-03-30T00:07:18Z                   album
# ...     ...                   ...                     ...
# 2055      5  2016-05-24T09:41:01Z             compilation
# 2056      6  2016-05-24T09:40:58Z                   album
# 2057      7  2016-05-24T09:40:11Z                   album
# 2058      8  2016-05-24T09:39:42Z                   album
# 2059      9  2016-05-24T09:35:11Z                   album
#
#      track.album.album_type  \
# 0                     album
# 1                    single
# 2                     album
# 3                     album
# 4                     album
# ...                     ...
# 2055            compilation
# 2056                  album
# ...

# %%
genres
# Out:
# [['detroit hip hop', 'hip hop', 'rap'],
#  ['alternative rock',
#   'blues rock',
#   'detroit rock',
#   'garage rock',
#   'modern blues rock',
#   'modern rock',
#   'permanent wave',
#   'punk blues',
#   'rock'],
#  ['musica mexicana', 'norteno'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
#  ['pop'],
# ...

# %%
LIB['genre'] = genres

# %%
LIB
# Out:
#       index              added_at track.album.album_group  \
# 0         0  2023-04-04T23:47:45Z                   album
# 1         1  2023-03-30T11:28:56Z                  single
# 2         2  2023-03-30T01:49:21Z                   album
# 3         3  2023-03-30T00:07:23Z                   album
# 4         4  2023-03-30T00:07:18Z                   album
# ...     ...                   ...                     ...
# 2055      5  2016-05-24T09:41:01Z             compilation
# 2056      6  2016-05-24T09:40:58Z                   album
# 2057      7  2016-05-24T09:40:11Z                   album
# 2058      8  2016-05-24T09:39:42Z                   album
# 2059      9  2016-05-24T09:35:11Z                   album
#
#      track.album.album_type  \
# 0                     album
# 1                    single
# 2                     album
# 3                     album
# 4                     album
# ...                     ...
# 2055            compilation
# 2056                  album
# ...

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))
def get_genre(track_id):
    
    track_info = sp.track(track_id)
    
#     genre = track_info['artists'][0]['genres'][0]
    return track_info

# %%
def get_genre(track_id):
    
    # Get track info
    track_info = sp.track(track_id)
    
    # Get artist info
    artist_info = sp.artist(track_info['artists'][0]['id'])
    
    # Get genre
    genre = artist_info['genres']
    
    return genre

# %%
genres = []
for track_id in LIB['track.id']:
    genres.append(get_genre(track_id))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7340\1984403400.py in <module>
#       1 genres = []
#       2 for track_id in LIB['track.id']:
# ----> 3     genres.append(get_genre(track_id))
#
# ~\AppData\Local\Temp\ipykernel_7340\2706888567.py in get_genre(track_id)
#       5
#       6     # Get artist info
# ----> 7     artist_info = sp.artist(track_info['artists'][0]['id'])
#       8
#       9     # Get genre
#
# ~\AppData\Roaming\Python\Python39\site-packages\spotipy\client.py in artist(self, artist_id)
#     388
#     389         trid = self._get_id("artist", artist_id)
# --> 390         return self._get("artists/" + trid)
#     391
#     392     def artists(self, artists):
#
# ~\AppData\Roaming\Python\Python39\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     319             kwargs.update(args)
#     320
# ...

# %%
len(genres)

# %%
genres

# %%
from langdetect import detect

# Replace this with the lyrics of the song you want to detect the language for
lyrics = """
Freitag, Samstag fick' ich meinen Kopf
Feier' ich non-stop, mach' mir keinen Kopf (Brrt)
Freitag, Samstag fick' ich meinen Kopf (Fuck it)
Feier' ich non-stop (Brra), gib mir noch 'nen Shot (Brrt)

[Refrain: ?]
Freitag, Samstag fick' ich meinen Kopf (Skrrt)
Feier' ich non-stop (Ough), mach' mir keinen Kopf
Freitag, Samstag fick' ich meinen Kopf (Brra)
Feier' ich non-stop (Ey), gib mir noch 'nen Shot
Shot, Shot, Shot, Shot, Shot, Shot, Shot, Shot—
Freitag, Samstag fick' ich meinen Kopf
"""

# Detect the language of the lyrics
detected_lang = detect(lyrics)

# Print the detected language
print("Detected Language:", detected_lang)
# Out:
# Detected Language: de

# %%
LYRICS['language'] = LYRICS['lyrics'].apply(detect)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7340\2718528189.py in <module>
# ----> 1 LYRICS['language'] = LYRICS['lyrics'].apply(detect)
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
# ...

# %%
for i in LYRICS.index:
    if LYRICS['lyrics'][i].isna():
        print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7340\2226110019.py in <module>
#       1 for i in LYRICS.index:
# ----> 2     if LYRICS['lyrics'][i].isna():
#       3         print(i)
#
# AttributeError: 'str' object has no attribute 'isna'

# %%
LYRICS['lyrics'][2]
# Out:
# nan

# %%
import lyricsgenius

# insert your Genius API credentials here
genius = lyricsgenius.Genius(get_access_token())
print(2)
# get the song and artist names from the user
song_name = 'Someone Like You'
artist_name = 'Adele'

# search for the song on Genius
song = genius.search_song(song_name, artist_name)

# print the lyrics if we found the song
if song:
    print(song.lyrics)
else:
    print("Sorry, couldn't find the lyrics for that song.")
# Out:
# 2
# Searching for "Someone Like You" by Adele...
# Done.
# TranslationsEspañolΕλληνικάفارسیSomeone Like You Lyrics[Verse 1]
# I heard that you're settled down
# That you found a girl and you're married now
# I heard that your dreams came true
# Guess she gave you things I didn't give to you
# Old friend, why are you so shy?
# Ain't like you to hold back or hide from the light
#
# [Pre-Chorus]
# I hate to turn up out of the blue, uninvited
# But I couldn't stay away, I couldn't fight it
# I had hoped you'd see my face
# And that you'd be reminded that for me, it isn't over
# [Chorus]
# Never mind, I'll find someone like you
# I wish nothing but the best for you, too
# Don't forget me, I beg
# I remember you said
# Sometimes it lasts in love, but sometimes it hurts instead
# Sometimes it lasts in love, but sometimes it hurts instead
#
# [Verse 2]
# You know how the time flies
# Only yesterday was the time of our lives
# We were born and raised in a summer haze
# ...

# %%
song.lyrics
# Out:
# "TranslationsEspañolΕλληνικάفارسیSomeone Like You Lyrics[Verse 1]\nI heard that you're settled down\nThat you found a girl and you're married now\nI heard that your dreams came true\nGuess she gave you things I didn't give to you\nOld friend, why are you so shy?\nAin't like you to hold back or hide from the light\n\n[Pre-Chorus]\nI hate to turn up out of the blue, uninvited\nBut I couldn't stay away, I couldn't fight it\nI had hoped you'd see my face\nAnd that you'd be reminded that for me, it isn't over\n[Chorus]\nNever mind, I'll find someone like you\nI wish nothing but the best for you, too\nDon't forget me, I beg\nI remember you said\nSometimes it lasts in love, but sometimes it hurts instead\nSometimes it lasts in love, but sometimes it hurts instead\n\n[Verse 2]\nYou know how the time flies\nOnly yesterday was the time of our lives\nWe were born and raised in a summer haze\nBound by the surprise of our glory days\n\n[Pre-Chorus]\nI hate to turn up out of the blue, uninvited\nB
# ...

# %%
type(song.lyrics)
# Out:
# str

# %%
# Out:
# TranslationsEspañolΕλληνικάفارسیSomeone Like You Lyrics[Verse 1]
# I heard that you're settled down
# That you found a girl and you're married now
# I heard that your dreams came true
# Guess she gave you things I didn't give to you
# Old friend, why are you so shy?
# Ain't like you to hold back or hide from the light
#
# [Pre-Chorus]
# I hate to turn up out of the blue, uninvited
# But I couldn't stay away, I couldn't fight it
# I had hoped you'd see my face
# And that you'd be reminded that for me, it isn't over
# [Chorus]
# Never mind, I'll find someone like you
# I wish nothing but the best for you, too
# Don't forget me, I beg
# I remember you said
# Sometimes it lasts in love, but sometimes it hurts instead
# Sometimes it lasts in love, but sometimes it hurts instead
#
# [Verse 2]
# You know how the time flies
# Only yesterday was the time of our lives
# We were born and raised in a summer haze
# Bound by the surprise of our glory days
#
# [Pre-Chorus]
# ...
